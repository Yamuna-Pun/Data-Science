# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
text = "This is the test content fot the objective"

# %%
text
# Out:
# 'This is the test content fot the objective'

# %%
word_tokenize(text)
# Out:
# ['This', 'is', 'the', 'test', 'content', 'fot', 'the', 'objective']

# %%
import nltk

# %%
from nltk.tokenize import word_tokenize

# %%
text = " I am Yamuna Pun, This is data science class at 10:30 with respected roshan shrestha sir!!"

# %%
text
# Out:
# ' I am Yamuna Pun, This is data science class at 10:30 with respected roshan shrestha sir!!'

# %%
word_tokenize(text)
# Out:
# ['I',
#  'am',
#  'Yamuna',
#  'Pun',
#  ',',
#  'This',
#  'is',
#  'data',
#  'science',
#  'class',
#  'at',
#  '10:30',
#  'with',
#  'respected',
#  'roshan',
#  'shrestha',
#  'sir',
#  '!',
#  '!']

# %%
from nltk.tokenize import sent_tokenize

# %%
text1 = "Hello I am Yamuna Pun Pun Magar! This is my test in Data Science "

# %%
text1
# Out:
# 'Hello I am Yamuna Pun Pun Magar! This is my test in Data Science '

# %%
sent_tokenize(text1)
# Out:
# ['Hello I am Yamuna Pun Pun Magar!', 'This is my test in Data Science']

# %%
token_word=word_tokenize(text1)

# %%
token_word
# Out:
# ['Hello',
#  'I',
#  'am',
#  'Yamuna',
#  'Pun',
#  'Pun',
#  'Magar',
#  '!',
#  'This',
#  'is',
#  'my',
#  'test',
#  'in',
#  'Data',
#  'Science']

# %%
from nltk.probability import FreqDist

# %%
token_word = word_tokenize(text1)

# %%
freq = FreqDist(token_word)

# %%
freq
# Out:
# FreqDist({'Pun': 2, 'Hello': 1, 'I': 1, 'am': 1, 'Yamuna': 1, 'Magar': 1, '!': 1, 'This': 1, 'is': 1, 'my': 1, ...})

# %%
token_word = sent_tokenize(text1)

# %%
sep = FreqDist(token_word)

# %%
sep
# Out:
# FreqDist({'Hello I am Yamuna Pun Pun Magar!': 1, 'This is my test in Data Science': 1})

# %%
import matplotlib.pyplot as plt

# %%
freq.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
freq.plot(7)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
sep.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
sep.plot(6)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
text2 = "This is my Data Science Class at 10:30 in Respected Roshan Shrestha Sir, and This is my test "

# %%
text2
# Out:
# 'This is my Data Science Class at 10:30 in Respected Roshan Shrestha Sir, and This is my test '

# %%
word_tokenize(text2)
# Out:
# ['This',
#  'is',
#  'my',
#  'Data',
#  'Science',
#  'Class',
#  'at',
#  '10:30',
#  'in',
#  'Respected',
#  'Roshan',
#  'Shrestha',
#  'Sir',
#  ',',
#  'and',
#  'This',
#  'is',
#  'my',
#  'test']

# %%
sent_tokenize(text2)
# Out:
# ['This is my Data Science Class at 10:30 in Respected Roshan Shrestha Sir, and This is my test']

# %%
token_word = sent_tokenize(text1)
test = FreqDist(text2)
test
# Out:
# FreqDist({' ': 18, 's': 10, 'i': 7, 'a': 7, 'e': 7, 't': 6, 'h': 5, 'n': 4, 'S': 3, 'c': 3, ...})

# %%
test.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
test.plot(7)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
token_word = word_tokenize(text2)
testing = FreqDist(text2)
testing
# Out:
# FreqDist({' ': 18, 's': 10, 'i': 7, 'a': 7, 'e': 7, 't': 6, 'h': 5, 'n': 4, 'S': 3, 'c': 3, ...})

# %%
testing.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
testing.plot(8)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
