# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('dm_office_sales.csv')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(15,3))
sns.rugplot(data=df,x='salary')
# not exist of y axist
# Out:
# <Axes: xlabel='salary'>

# %%
df.salary.unique()
# Out:
# array([ 91684, 119679,  82045,  92949,  71280, 102401,  77548,  81966,
#         72844,  96731,  73508,  97841,  82719,  98070,  94604, 105864,
#         79103,  70834, 109279,  77126, 100478, 120849, 104805, 101064,
#         93307,  79557, 103623, 103102,  90624,  86992, 107167, 109170,
#         77464,  75556,  71739,  71754,  82212,  72889, 103149,  83792,
#         98668,  87697,  72061,  89007, 106439, 116489, 102285, 117441,
#         70683,  73325, 102889, 128685, 122039,  94155,  91294,  94787,
#        113059, 128460,  71579,  77722,  52324,  86125,  76575,  46061,
#         89958, 101181, 121184,  57580, 122903,  87644,  93659,  81859,
#         97604,  99223, 100790,  82876,  91973,  75155,  79042, 103816,
#        112198, 104068,  77010, 107821,  92038,  93920,  91768, 106885,
#         90970,  70523, 114278,  60365,  67849,  82344,  90567,  79247,
#         73426,  92602,  86105, 138975, 103966, 101638,  64852, 159148,
# ...

# %%
plt.figure(figsize=(6,4),dpi=150)
sns.rugplot(data=df,x='salary',height=0.5)
# Out:
# <Axes: xlabel='salary'>

# %%
sns.rugplot(data=df,x='level of education',height=0.5)
# Out:
# <Axes: xlabel='level of education'>

# %%
sns.displot(data=df,x='salary');

# %%
plt.figure(dpi=150)
sns.displot(data=df,x='salary',bins=20);
# meaning of bins are distance of length value

# %%
#KDE kernal density estimation.
sns.displot(data=df,x='salary',bins=10,color='blue',edgecolor='black',kde='True',linewidth=5,ls='--');
#curve

# %%
#eda

# %%
plt.figure(figsize=(2,2),dpi=200)
sns.histplot(data=df,x='salary',color='red')
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.kdeplot(data=df,x='salary',color='green')
# Out:
# <Axes: xlabel='salary', ylabel='Density'>

# %%
plt.figure(figsize=(4,3),dpi=200) #4 is length 3 is hight
sns.histplot(data=df,x='sales',color='red')
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['division', 'level of education', 'training level', 'work experience',
#        'salary', 'sales'],
#       dtype='object')

# %%
df['division'].value_counts()
# Out:
# office supplies      252
# printers             250
# peripherals          243
# computer hardware    159
# computer software     96
# Name: division, dtype: int64

# %%
df['division'].value_counts().sum()
# Out:
# 1000

# %%
#a mins add the front box and b mins add the back box

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.countplot(df,x='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
color=['red','red','red','red']
plt.figure(figsize=(10,5),dpi=200)
sns.countplot(df,x='level of education', hue='division')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.countplot(df,x='salary', hue='level of education')
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
plt.figure(figsize=(10,5),dpi=200)
sns.barplot(df,x='level of education', y='salary')
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(df,x='division',palette='husl')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
# 1 colums 0 rows

# %%
df.drop('sales',axis=1)
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary
# 0     91684
# 1    119679
# 2     82045
# ...

# %%
df.describe()
# Out:
#        training level  work experience         salary          sales
# count     1000.000000       1000.00000    1000.000000    1000.000000
# mean         1.262000          6.14200   90264.207000  339833.846000
# std          0.925317          2.94797   17398.617174  108555.773316
# min          0.000000          0.00000   41660.000000   53067.000000
# 25%          1.000000          4.00000   77584.000000  259257.500000
# 50%          1.000000          6.00000   89946.000000  338145.500000
# 75%          2.000000          8.00000  101834.250000  415210.250000
# max          3.000000         16.00000  159148.000000  761477.000000
