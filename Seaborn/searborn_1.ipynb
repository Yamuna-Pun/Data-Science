# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv('Salary_Data.csv')

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sns.scatterplot(df,x='Salary',y='YearsExperience')
# Out:
# <Axes: xlabel='Salary', ylabel='YearsExperience'>

# %%
plt.figure(figsize=(12,5),dpi=350)
sns.scatterplot(df,x='Salary',y='YearsExperience',s=300)
# Out:
# <Axes: xlabel='Salary', ylabel='YearsExperience'>

# %%
df=pd.read_csv('Salary Data.csv')

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
sns.scatterplot(df,x='Salary',y='Years of Experience')
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(df,x='Salary',y='Years of Experience')
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %%
sns.scatterplot(df,y='Salary',x='Years of Experience')
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Salary'>

# %%
df.Salary
# Out:
# 0       90000.0
# 1       65000.0
# 2      150000.0
# 3       60000.0
# 4      200000.0
#          ...
# 370     85000.0
# 371    170000.0
# 372     40000.0
# 373     90000.0
# 374    150000.0
# Name: Salary, Length: 375, dtype: float64

# %%
df['Years of Experience']
# Out:
# 0       5.0
# 1       3.0
# 2      15.0
# 3       7.0
# 4      20.0
#        ...
# 370     8.0
# 371    19.0
# 372     2.0
# 373     7.0
# 374    15.0
# Name: Years of Experience, Length: 375, dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(df,x='Salary',y='Years of Experience', hue='Education Level')
#hue add that can be 3D animation
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(df,x='Salary',y='Years of Experience',hue='Education Level',s=500)
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %%
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(df,x='Salary',y='Years of Experience',hue='Education Level',s=300,alpha=0.5)
# Out:
# <Axes: xlabel='Salary', ylabel='Years of Experience'>

# %%
plt.figure(figsize=(4,4),dpi=200)
sns.scatterplot(df,x='Salary',y='Years of Experience',style='Education Level')
plt.savefig('test1demo.png')

# %%
ML
training 
testing
